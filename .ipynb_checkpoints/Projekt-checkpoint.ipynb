# %%
#import knižníc

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Načítanie vstupných dát

df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
# import 303 premených (x = vek,pohlavie a y = stav infarktu)

x = df.iloc[0:302,[0,1]].values
y = df.iloc[0:302,[13]].values
x
# Out:
# array([[63,  1],
#        [37,  1],
#        [41,  0],
#        [56,  1],
#        [57,  0],
#        [57,  1],
#        [56,  0],
#        [44,  1],
#        [52,  1],
#        [57,  1],
#        [54,  1],
#        [48,  0],
#        [49,  1],
#        [64,  1],
#        [58,  0],
#        [50,  0],
#        [58,  0],
#        [66,  0],
#        [43,  1],
#        [69,  0],
#        [59,  1],
#        [44,  1],
#        [42,  1],
#        [61,  1],
#        [40,  1],
#        [71,  0],
#        [59,  1],
#        [51,  1],
#        [65,  0],
#        [53,  1],
#        [41,  0],
#        [65,  1],
#        [44,  1],
#        [54,  1],
#        [51,  1],
#        [46,  0],
#        [54,  0],
#        [54,  1],
#        [65,  0],
#        [65,  0],
#        [51,  0],
#        [48,  1],
#        [45,  1],
#        [53,  0],
#        [39,  1],
#        [52,  1],
#        [44,  1],
#        [47,  1],
#        [53,  0],
#        [53,  0],
#        [51,  0],
#        [66,  1],
# ...

# %%
plt.scatter(x[:165,0],x[:165,1],color='blue',label='infarkt')
plt.scatter(x[165:300,0],x[165:300,1],color='red',label='bez infarktu')

plt.xlabel('vek')
plt.ylabel('pohlavie')

plt.legend()
plt.show()
